# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 25.2 is available.
# You should consider upgrading via the '/home/ec2-user/7-retain-at-risk-1/.venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#      Month  RowID        Response ID  \
# 0  October    101  R_Y3LSnMS91cFvTUZ
# 1  October    677  R_1MSpOeErO1vMEno
# 2  October    667  R_28zIRj9xXv5UT2p
# 3  October    270  R_2CqOiVX3yrj9Rd4
# 4  October    341  R_3Jla1YNQA0hntPd
#
#   Overall, how satisfied are you with your experience living on campus at SDSU in the last 30 days?  \
# 0                                          Satisfied
# 1                                          Satisfied
# 2                                          Satisfied
# 3                                          Satisfied
# 4                                          Satisfied
#
#   Please explain why you are not satisfied with your experience living on campus at SDSU:  \
# 0                                     Did not answer
# 1                                     Did not answer
# 2                                     Did not answer
# 3                                     Did not answer
# 4                                     Did not answer
#
# ...

# %%
df.columns
# Out:
# Index(['Month', 'RowID', 'Response ID',
#        'Overall, how satisfied are you with your experience living on campus at SDSU in the last 30 days?',
#        'Please explain why you are not satisfied with your experience living on campus at SDSU:',
#        'Front Desk', 'Wepa Printing Kiosk', 'Laundry Facilities',
#        'Outdoor Recreation Facilities (pool, patio, fire pit, etc.)',
#        'The UPS Store', 'Streeme TV or Cable', 'WiFi',
#        'Residential Bike Storage and Bike Racks', 'Surfboard Storage',
#        'Community Study Areas', 'Community Kitchens', 'Vending Machines',
#        'Have you utilized a STAR Center in the last 30 days?',
#        'Please explain why you are not using the Star Center:',
#        'Cleanliness of your residential community common areas (bathrooms, laundry rooms, hallways, lounges)',
#        'Maintenance of your residential community (furniture, utilities, appliances)',
# ...

# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 25.2 is available.
# You should consider upgrading via the '/home/ec2-user/7-retain-at-risk-1/.venv/bin/python3 -m pip install --upgrade pip' command.

# %%
df["Gender"].value_counts()
# Out:
# Gender
# F    570
# M    189
# U      3
# Name: count, dtype: int64

# %%
df["Gender"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
encoded_df = pd.get_dummies(df, columns=[
    "how confident are you in preparing a nutritious, healthy meal for yourself?",
    "how confident are you that you can make healthy food choices?"
])
encoded_df.head()
# Out:
#      Month  RowID        Response ID  \
# 0  October    101  R_Y3LSnMS91cFvTUZ
# 1  October    677  R_1MSpOeErO1vMEno
# 2  October    667  R_28zIRj9xXv5UT2p
# 3  October    270  R_2CqOiVX3yrj9Rd4
# 4  October    341  R_3Jla1YNQA0hntPd
#
#   Overall, how satisfied are you with your experience living on campus at SDSU in the last 30 days?  \
# 0                                          Satisfied
# 1                                          Satisfied
# 2                                          Satisfied
# 3                                          Satisfied
# 4                                          Satisfied
#
#   Please explain why you are not satisfied with your experience living on campus at SDSU:  \
# 0                                     Did not answer
# 1                                     Did not answer
# 2                                     Did not answer
# 3                                     Did not answer
# 4                                     Did not answer
#
# ...

# %%
encoded_df= pd.get_dummies(df, columns=["RLC_GroupCoded", "Attended a campus event", "Participated in a religious or spiritual group"])
encoded_df.head()
# Out:
#      Month  RowID        Response ID  \
# 0  October    101  R_Y3LSnMS91cFvTUZ
# 1  October    677  R_1MSpOeErO1vMEno
# 2  October    667  R_28zIRj9xXv5UT2p
# 3  October    270  R_2CqOiVX3yrj9Rd4
# 4  October    341  R_3Jla1YNQA0hntPd
#
#   Overall, how satisfied are you with your experience living on campus at SDSU in the last 30 days?  \
# 0                                          Satisfied
# 1                                          Satisfied
# 2                                          Satisfied
# 3                                          Satisfied
# 4                                          Satisfied
#
#   Please explain why you are not satisfied with your experience living on campus at SDSU:  \
# 0                                     Did not answer
# 1                                     Did not answer
# 2                                     Did not answer
# 3                                     Did not answer
# 4                                     Did not answer
#
# ...

# %%
# !pip install seaborn
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 25.2 is available.
# You should consider upgrading via the '/home/ec2-user/7-retain-at-risk-1/.venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only the columns related to the confidence questions
confidence_columns = [col for col in encoded_df.columns if col.startswith("how confident")]
confidence_df = encoded_df[confidence_columns]

plt.figure(figsize=(8, 5))
sns.heatmap(confidence_df.head(20), annot=True, cbar=True, cmap="YlGnBu")
plt.title("Heatmap of Confidence Encodings (First 20 Rows)")
plt.xlabel("Encoding")
plt.ylabel("Sample Index")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load your DataFrame (replace with your actual data source)
# df = pd.read_csv('your_data.csv')

# For demonstration, assume df is already defined in your environment
nutri_cols = [
    'Eat at an on-campus eatery (Food trucks, restaurants, food court)',
    'Prepared a meal on my own',
    'Eat with friends',
    'Eat alone'
]

# 2. One-hot encode the nutritional columns
encoded = pd.get_dummies(df[nutri_cols])
encoded_df = pd.concat([df, encoded], axis=1)

# 3. Plot individual heatmaps for the first 20 rows of each encoded variable
for col in nutri_cols:
    encoded_cols = [c for c in encoded_df.columns if c.startswith(col + '_')]
    data = encoded_df[encoded_cols].head(20)
    
    plt.figure(figsize=(6, 4))
    plt.imshow(data, aspect='auto', interpolation='nearest')
    plt.colorbar(label='0 or 1')
    
    plt.xticks(range(len(encoded_cols)), encoded_cols, rotation=45, ha='right')
    plt.yticks(range(20), range(1, 21))
    
    plt.title(f"Heatmap of '{col}' Encoding (First 20 Rows)")
    plt.xlabel("Category")
    plt.ylabel("Sample Index")
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 16
#       8 nutri_cols = [
#       9     'Eat at an on-campus eatery (Food trucks, restaurants, food court)',
#      10     'Prepared a meal on my own',
#      11     'Eat with friends',
#      12     'Eat alone'
#      13 ]
#      15 # 2. One-hot encode the nutritional columns
# ---> 16 encoded = pd.get_dummies(df[nutri_cols])
#      17 encoded_df = pd.concat([df, encoded], axis=1)
#      19 # 3. Plot individual heatmaps for the first 20 rows of each encoded variable
#
# File ~/7-retain-at-risk-1/.venv/lib64/python3.9/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# -> 4113     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4115 # take() does not accept boolean indexers
# ...

# %%
for c in df.columns:
    print(repr(c))
# Out:
# 'Month'
# 'RowID'
# 'Response ID'
# 'Overall, how satisfied are you with your experience living on campus at SDSU in the last 30 days?'
# 'Please explain why you are not satisfied with your experience living on campus at SDSU:'
# 'Front Desk'
# 'Wepa Printing Kiosk'
# 'Laundry Facilities'
# 'Outdoor Recreation Facilities (pool, patio, fire pit, etc.)'
# 'The UPS Store'
# 'Streeme TV or Cable'
# 'WiFi'
# 'Residential Bike Storage and Bike Racks'
# 'Surfboard Storage'
# 'Community Study Areas'
# 'Community Kitchens'
# 'Vending Machines'
# 'Have you utilized a STAR Center in the last 30 days?'
# 'Please explain why you are not using the Star Center:'
# 'Cleanliness of your residential community common areas (bathrooms, laundry rooms, hallways, lounges)'
# 'Maintenance of your residential community (furniture, utilities, appliances)'
# 'Amenities of your residential community (i.e., wifi, lounges, furniture, laundry, outdoor recreational spaces)'
# ...

# %%
for c in df.columns:
    low = c.lower()
    if ("campus eatery" in low
        or "prepared a meal on my own" in low
        or "eat with friends" in low
        or "eat alone" in low):
        print(c)
# Out:
# Eat at an on campus eatery (Food trucks, restaurants, food court)
# Prepared a meal on my own
# Eat with friends
# Eat alone

# %%
import matplotlib.pyplot as plt

# Create bar charts for each nutritional column
nutri_cols = [
    "Eat at an on campus eatery (Food trucks, restaurants, food court)",
    "Prepared a meal on my own", 
    "Eat with friends",
    "Eat alone"
]

fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.ravel()

for idx, col in enumerate(nutri_cols):
    value_counts = df[col].value_counts()
    axes[idx].bar(value_counts.index, value_counts.values)
    axes[idx].set_title(col)
    axes[idx].set_xlabel('Response')
    axes[idx].set_ylabel('Count')
    axes[idx].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

nutri_cols = [
    "Eat at an on campus eatery (Food trucks, restaurants, food court)",
    "Prepared a meal on my own",
    "Eat with friends",
    "Eat alone"
]

encoded_nutri = pd.get_dummies(df[nutri_cols], prefix_sep="_")

print("New one-hot columns:")
print(encoded_nutri.columns.tolist())

plt.figure(figsize=(14,6))
sns.heatmap(
    encoded_nutri.head(20),
    annot=True,
    cbar=True,
    cmap="YlGnBu",
    linewidths=0.5
)
plt.xticks(rotation=90)
plt.title("Nutritional Questions One-Hot (First 20 Samples)")
plt.xlabel("Encoded Category")
plt.ylabel("Sample Index")
plt.tight_layout()
plt.show()
# Out:
# New one-hot columns:
# ['Eat at an on campus eatery (Food trucks, restaurants, food court)_0 Times', 'Eat at an on campus eatery (Food trucks, restaurants, food court)_1-5 Times', 'Eat at an on campus eatery (Food trucks, restaurants, food court)_6-10 Times', 'Eat at an on campus eatery (Food trucks, restaurants, food court)_Did not answer', 'Eat at an on campus eatery (Food trucks, restaurants, food court)_More than 10 Times', 'Prepared a meal on my own_0 Times', 'Prepared a meal on my own_1-5 Times', 'Prepared a meal on my own_6-10 Times', 'Prepared a meal on my own_Did not answer', 'Prepared a meal on my own_More than 10 Times', 'Eat with friends_0 Times', 'Eat with friends_1-5 Times', 'Eat with friends_6-10 Times', 'Eat with friends_Did not answer', 'Eat with friends_More than 10 Times', 'Eat alone_0 Times', 'Eat alone_1-5 Times', 'Eat alone_6-10 Times', 'Eat alone_Did not answer', 'Eat alone_More than 10 Times']
# ...

# %%
for q in nutri_cols:
    cols = [c for c in encoded_nutri.columns if c.startswith(q + "_")]
    sns.heatmap(encoded_nutri[cols].head(20), annot=True, cbar=False,
                cmap="YlGnBu", linewidths=.5)
    plt.title(q)
    plt.xticks(rotation=45, ha="right")
    plt.yticks(rotation=0)
    plt.show()
